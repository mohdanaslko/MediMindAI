# %%
import pandas as pd

# %%
description_df = pd.read_csv(r"C:\Users\anasm\Documents\MediMindAI\datasets\symptom_Description.csv")
description_df.head()
# Out:
#           Disease                                        Description
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...

# %%
listt = description_df['Disease'].values.tolist()
listt[0]
# Out:
# 'Drug Reaction'

# %%
description_df['Disease'].values.tolist().index('AIDS')
# Out:
# 23

# %%
description_df['Description'][23]
# Out:
# "Acquired immunodeficiency syndrome (AIDS) is a chronic, potentially life-threatening condition caused by the human immunodeficiency virus (HIV). By damaging your immune system, HIV interferes with your body's ability to fight infection and disease."
